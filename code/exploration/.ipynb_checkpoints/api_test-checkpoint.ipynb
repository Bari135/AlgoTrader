# %%
import requests
import pandas as pd
import json
from dateutil import parser

# %%
API_KEY = "41e931078da8d27b7e4befaab7450b98-4707abfc0f53775372778340d7fcda02"
ACCOUNT_ID = "101-001-26602725-001"
OANDA_URL = "https://api-fxpractice.oanda.com/v3"

# %%
#נפתח סשן שממנו נבקש את כל השיט
#הפואנטה בסשן-אפשר להגדיר "כותרות" (headers) שהם קבועות וצריך אותן בכל בקשה

# %%
session = requests.Session()

# %%
session.headers.update({"Authorization": f"Bearer {API_KEY}",
                        "Content-Type": "application/json"
                       })

# %%
params = dict(
    count = 10,
    granularity = "H1",
    price = "MBA"
)

# %%
url= f"{OANDA_URL}/accounts/{ACCOUNT_ID}/instruments"

# %%
response = session.get(url, params = None, data=None, headers=None)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "complete": true,
#     "volume": 5803,
#     "time": "2023-08-16T07:00:00.000000000Z",
#     "bid": {
#       "o": "1.35020",
#       "h": "1.35037",
#       "l": "1.34808",
#       "c": "1.34873"
#     },
#     "mid": {
#       "o": "1.35030",
#       "h": "1.35048",
#       "l": "1.34817",
#       "c": "1.34882"
#     },
#     "ask": {
#       "o": "1.35041",
#       "h": "1.35060",
#       "l": "1.34826",
#       "c": "1.34891"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4647,
#     "time": "2023-08-16T08:00:00.000000000Z",
#     "bid": {
#       "o": "1.34875",
#       "h": "1.34895",
#       "l": "1.34746",
#       "c": "1.34799"
#     },
#     "mid": {
#       "o": "1.34884",
#       "h": "1.34905",
#       "l": "1.34756",
#       "c": "1.34808"
#     },
#     "ask": {
#       "o": "1.34894",
#       "h": "1.34915",
#       "l": "1.34764",
#       "c": "1.34818"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4477,
#     "time": "2023-08-16T09:00:00.000000000Z",
#     "bid": {
#       "o": "1.34800",
#       "h": "1.34927",
#       "l": "1.34745",
#       "c": "1.34882"
#     },
#     "mid": {
#       "o": "1.34809",
#       "h": "1.34936",
#       "l": "1.34754",
#       "c": "1.34890"
#     },
#     "ask": {
#       "o": "1.34818",
#       "h": "1.34947",
#       "l": "1.34764",
#       "c": "1.34898"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4312,
#     "time": "2023-08-16T10:00:00.000000000Z",
#     "bid": {
#       "o": "1.34880",
#       "h": "1.34989",
#       "l": "1.34855",
#       "c": "1.34949"
#     },
#     "mid": {
#       "o": "1.34890",
#       "h": "1.34998",
#       "l": "1.34864",
#       "c": "1.34957"
#     },
#     "ask": {
#       "o": "1.34899",
#       "h": "1.35006",
#       "l": "1.34873",
#       "c": "1.34965"
#     }
#   },
#   {
#     "complete": false,
#     "volume": 2196,
#     "time": "2023-08-16T11:00:00.000000000Z",
#     "bid": {
#       "o": "1.34949",
#       "h": "1.34983",
#       "l": "1.34899",
#       "c": "1.34912"
#     },
#     "mid": {
#       "o": "1.34958",
#       "h": "1.34993",
#       "l": "1.34908",
#       "c": "1.34922"
#     },
#     "ask": {
#       "o": "1.34966",
#       "h": "1.35003",
#       "l": "1.34916",
#       "c": "1.34933"
#     }
#   }
# ]

# %%
data.keys()
# Out:
# dict_keys(['instruments', 'lastTransactionID'])

# %%
instruments_list = data['instruments']
len(instruments_list)
# Out:
# 68

# %%
print(json.dumps(instruments_list[0], indent=2))
# Out:
# {
#   "name": "EUR_ZAR",
#   "type": "CURRENCY",
#   "displayName": "EUR/ZAR",
#   "pipLocation": -4,
#   "displayPrecision": 5,
#   "tradeUnitsPrecision": 0,
#   "minimumTradeSize": "1",
#   "maximumTrailingStopDistance": "1.00000",
#   "minimumTrailingStopDistance": "0.00050",
#   "maximumPositionSize": "0",
#   "maximumOrderUnits": "100000000",
#   "marginRate": "0.07",
#   "guaranteedStopLossOrderMode": "DISABLED",
#   "tags": [
#     {
#       "type": "ASSET_CLASS",
#       "name": "CURRENCY"
#     }
#   ],
#   "financing": {
#     "longRate": "-0.0695",
#     "shortRate": "0.0247",
#     "financingDaysOfWeek": [
#       {
#         "dayOfWeek": "MONDAY",
#         "daysCharged": 1
#       },
#       {
#         "dayOfWeek": "TUESDAY",
#         "daysCharged": 1
#       },
#       {
#         "dayOfWeek": "WEDNESDAY",
#         "daysCharged": 1
#       },
#       {
#         "dayOfWeek": "THURSDAY",
#         "daysCharged": 1
#       },
#       {
#         "dayOfWeek": "FRIDAY",
#         "daysCharged": 1
#       },
#       {
#         "dayOfWeek": "SATURDAY",
#         "daysCharged": 0
#       },
#       {
#         "dayOfWeek": "SUNDAY",
#         "daysCharged": 0
#       }
#     ]
#   }
# }

# %%
instruments_list[0].keys()
# Out:
# dict_keys(['name', 'type', 'displayName', 'pipLocation', 'displayPrecision', 'tradeUnitsPrecision', 'minimumTradeSize', 'maximumTrailingStopDistance', 'minimumTrailingStopDistance', 'maximumPositionSize', 'maximumOrderUnits', 'marginRate', 'guaranteedStopLossOrderMode', 'tags', 'financing'])

# %%
interesting_keys=['name', 'type', 'displayName', 'pipLocation',
                  'displayPrecision', 'tradeUnitsPrecision', 'marginRate']

# %%
instruments_dict = {}
for i in instruments_list:
    key = i['name']
    instruments_dict[key] = { k: i[k] for k in interesting_keys }

# %%
print(json.dumps(instruments_dict, indent=2))
# Out:
# {
#   "EUR_ZAR": {
#     "name": "EUR_ZAR",
#     "type": "CURRENCY",
#     "displayName": "EUR/ZAR",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "EUR_CHF": {
#     "name": "EUR_CHF",
#     "type": "CURRENCY",
#     "displayName": "EUR/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.04"
#   },
#   "USD_PLN": {
#     "name": "USD_PLN",
#     "type": "CURRENCY",
#     "displayName": "USD/PLN",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "GBP_AUD": {
#     "name": "GBP_AUD",
#     "type": "CURRENCY",
#     "displayName": "GBP/AUD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_AUD": {
#     "name": "EUR_AUD",
#     "type": "CURRENCY",
#     "displayName": "EUR/AUD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "EUR_SGD": {
#     "name": "EUR_SGD",
#     "type": "CURRENCY",
#     "displayName": "EUR/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "NZD_CAD": {
#     "name": "NZD_CAD",
#     "type": "CURRENCY",
#     "displayName": "NZD/CAD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "TRY_JPY": {
#     "name": "TRY_JPY",
#     "type": "CURRENCY",
#     "displayName": "TRY/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.25"
#   },
#   "CAD_HKD": {
#     "name": "CAD_HKD",
#     "type": "CURRENCY",
#     "displayName": "CAD/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "USD_CHF": {
#     "name": "USD_CHF",
#     "type": "CURRENCY",
#     "displayName": "USD/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.04"
#   },
#   "AUD_HKD": {
#     "name": "AUD_HKD",
#     "type": "CURRENCY",
#     "displayName": "AUD/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "NZD_CHF": {
#     "name": "NZD_CHF",
#     "type": "CURRENCY",
#     "displayName": "NZD/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.04"
#   },
#   "AUD_CHF": {
#     "name": "AUD_CHF",
#     "type": "CURRENCY",
#     "displayName": "AUD/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.04"
#   },
#   "GBP_CHF": {
#     "name": "GBP_CHF",
#     "type": "CURRENCY",
#     "displayName": "GBP/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_THB": {
#     "name": "USD_THB",
#     "type": "CURRENCY",
#     "displayName": "USD/THB",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "GBP_CAD": {
#     "name": "GBP_CAD",
#     "type": "CURRENCY",
#     "displayName": "GBP/CAD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_HKD": {
#     "name": "EUR_HKD",
#     "type": "CURRENCY",
#     "displayName": "EUR/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "CHF_JPY": {
#     "name": "CHF_JPY",
#     "type": "CURRENCY",
#     "displayName": "CHF/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "GBP_HKD": {
#     "name": "GBP_HKD",
#     "type": "CURRENCY",
#     "displayName": "GBP/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "EUR_NZD": {
#     "name": "EUR_NZD",
#     "type": "CURRENCY",
#     "displayName": "EUR/NZD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "AUD_SGD": {
#     "name": "AUD_SGD",
#     "type": "CURRENCY",
#     "displayName": "AUD/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_JPY": {
#     "name": "EUR_JPY",
#     "type": "CURRENCY",
#     "displayName": "EUR/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_TRY": {
#     "name": "EUR_TRY",
#     "type": "CURRENCY",
#     "displayName": "EUR/TRY",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.25"
#   },
#   "USD_JPY": {
#     "name": "USD_JPY",
#     "type": "CURRENCY",
#     "displayName": "USD/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "SGD_JPY": {
#     "name": "SGD_JPY",
#     "type": "CURRENCY",
#     "displayName": "SGD/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "GBP_ZAR": {
#     "name": "GBP_ZAR",
#     "type": "CURRENCY",
#     "displayName": "GBP/ZAR",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "ZAR_JPY": {
#     "name": "ZAR_JPY",
#     "type": "CURRENCY",
#     "displayName": "ZAR/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "AUD_JPY": {
#     "name": "AUD_JPY",
#     "type": "CURRENCY",
#     "displayName": "AUD/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_ZAR": {
#     "name": "USD_ZAR",
#     "type": "CURRENCY",
#     "displayName": "USD/ZAR",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "CAD_JPY": {
#     "name": "CAD_JPY",
#     "type": "CURRENCY",
#     "displayName": "CAD/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "NZD_HKD": {
#     "name": "NZD_HKD",
#     "type": "CURRENCY",
#     "displayName": "NZD/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "USD_CZK": {
#     "name": "USD_CZK",
#     "type": "CURRENCY",
#     "displayName": "USD/CZK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_DKK": {
#     "name": "USD_DKK",
#     "type": "CURRENCY",
#     "displayName": "USD/DKK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.02"
#   },
#   "USD_SEK": {
#     "name": "USD_SEK",
#     "type": "CURRENCY",
#     "displayName": "USD/SEK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "GBP_SGD": {
#     "name": "GBP_SGD",
#     "type": "CURRENCY",
#     "displayName": "GBP/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_DKK": {
#     "name": "EUR_DKK",
#     "type": "CURRENCY",
#     "displayName": "EUR/DKK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "CHF_ZAR": {
#     "name": "CHF_ZAR",
#     "type": "CURRENCY",
#     "displayName": "CHF/ZAR",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "CAD_CHF": {
#     "name": "CAD_CHF",
#     "type": "CURRENCY",
#     "displayName": "CAD/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.04"
#   },
#   "GBP_USD": {
#     "name": "GBP_USD",
#     "type": "CURRENCY",
#     "displayName": "GBP/USD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_MXN": {
#     "name": "USD_MXN",
#     "type": "CURRENCY",
#     "displayName": "USD/MXN",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.10"
#   },
#   "USD_HUF": {
#     "name": "USD_HUF",
#     "type": "CURRENCY",
#     "displayName": "USD/HUF",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_HKD": {
#     "name": "USD_HKD",
#     "type": "CURRENCY",
#     "displayName": "USD/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "EUR_USD": {
#     "name": "EUR_USD",
#     "type": "CURRENCY",
#     "displayName": "EUR/USD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.02"
#   },
#   "EUR_CAD": {
#     "name": "EUR_CAD",
#     "type": "CURRENCY",
#     "displayName": "EUR/CAD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.02"
#   },
#   "AUD_CAD": {
#     "name": "AUD_CAD",
#     "type": "CURRENCY",
#     "displayName": "AUD/CAD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "GBP_PLN": {
#     "name": "GBP_PLN",
#     "type": "CURRENCY",
#     "displayName": "GBP/PLN",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_PLN": {
#     "name": "EUR_PLN",
#     "type": "CURRENCY",
#     "displayName": "EUR/PLN",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "GBP_NZD": {
#     "name": "GBP_NZD",
#     "type": "CURRENCY",
#     "displayName": "GBP/NZD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_HUF": {
#     "name": "EUR_HUF",
#     "type": "CURRENCY",
#     "displayName": "EUR/HUF",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_NOK": {
#     "name": "EUR_NOK",
#     "type": "CURRENCY",
#     "displayName": "EUR/NOK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "CHF_HKD": {
#     "name": "CHF_HKD",
#     "type": "CURRENCY",
#     "displayName": "CHF/HKD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "EUR_GBP": {
#     "name": "EUR_GBP",
#     "type": "CURRENCY",
#     "displayName": "EUR/GBP",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "AUD_NZD": {
#     "name": "AUD_NZD",
#     "type": "CURRENCY",
#     "displayName": "AUD/NZD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "CAD_SGD": {
#     "name": "CAD_SGD",
#     "type": "CURRENCY",
#     "displayName": "CAD/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "EUR_CZK": {
#     "name": "EUR_CZK",
#     "type": "CURRENCY",
#     "displayName": "EUR/CZK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "NZD_JPY": {
#     "name": "NZD_JPY",
#     "type": "CURRENCY",
#     "displayName": "NZD/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_TRY": {
#     "name": "USD_TRY",
#     "type": "CURRENCY",
#     "displayName": "USD/TRY",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.25"
#   },
#   "GBP_JPY": {
#     "name": "GBP_JPY",
#     "type": "CURRENCY",
#     "displayName": "GBP/JPY",
#     "pipLocation": -2,
#     "displayPrecision": 3,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "SGD_CHF": {
#     "name": "SGD_CHF",
#     "type": "CURRENCY",
#     "displayName": "SGD/CHF",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_CNH": {
#     "name": "USD_CNH",
#     "type": "CURRENCY",
#     "displayName": "USD/CNH",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "USD_NOK": {
#     "name": "USD_NOK",
#     "type": "CURRENCY",
#     "displayName": "USD/NOK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.07"
#   },
#   "NZD_SGD": {
#     "name": "NZD_SGD",
#     "type": "CURRENCY",
#     "displayName": "NZD/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   },
#   "NZD_USD": {
#     "name": "NZD_USD",
#     "type": "CURRENCY",
#     "displayName": "NZD/USD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "USD_CAD": {
#     "name": "USD_CAD",
#     "type": "CURRENCY",
#     "displayName": "USD/CAD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.02"
#   },
#   "AUD_USD": {
#     "name": "AUD_USD",
#     "type": "CURRENCY",
#     "displayName": "AUD/USD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "HKD_JPY": {
#     "name": "HKD_JPY",
#     "type": "CURRENCY",
#     "displayName": "HKD/JPY",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.1"
#   },
#   "EUR_SEK": {
#     "name": "EUR_SEK",
#     "type": "CURRENCY",
#     "displayName": "EUR/SEK",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.03"
#   },
#   "USD_SGD": {
#     "name": "USD_SGD",
#     "type": "CURRENCY",
#     "displayName": "USD/SGD",
#     "pipLocation": -4,
#     "displayPrecision": 5,
#     "tradeUnitsPrecision": 0,
#     "marginRate": "0.05"
#   }
# }

# %%
with open("../data/instruments.json", "w") as f:
    f.write(json.dumps(instruments_dict, indent=2))

# %%
#25-Fetching candles1
#פונקציה שתחזיר נרות על פי פרמטרים שאעביר לה
#הEND POINT הזה הרי מחזיר מילון עם 3 מפתחות, זה שאנחנו מעוניינים בו זה מפתח הCANDLES.
#הפואנטה של הפונקציה זה להביא לנו את הנרות בלבד (עם הפרמטרים שקיבלנו בפונקציה)

# %%
def fetch_candles(pairName, count=10, granularity="H1"):
    
    url = f"{OANDA_URL}/instruments/{pairName}/candles"
    
    params = dict(
        count = count,
        granularity = granularity,
        price = "MBA"
    )
    
    response = session.get(url, params = params, data=None, headers=None)
    data =response.json()

    if response.status_code == 200:
        if 'candles' not in data:
            data=[]
        else:
            data=data['candles']
        return response.status_code, data

# %%
code, data = fetch_candles("USD_CAD", count=5)

# %%
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "complete": true,
#     "volume": 5803,
#     "time": "2023-08-16T07:00:00.000000000Z",
#     "bid": {
#       "o": "1.35020",
#       "h": "1.35037",
#       "l": "1.34808",
#       "c": "1.34873"
#     },
#     "mid": {
#       "o": "1.35030",
#       "h": "1.35048",
#       "l": "1.34817",
#       "c": "1.34882"
#     },
#     "ask": {
#       "o": "1.35041",
#       "h": "1.35060",
#       "l": "1.34826",
#       "c": "1.34891"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4647,
#     "time": "2023-08-16T08:00:00.000000000Z",
#     "bid": {
#       "o": "1.34875",
#       "h": "1.34895",
#       "l": "1.34746",
#       "c": "1.34799"
#     },
#     "mid": {
#       "o": "1.34884",
#       "h": "1.34905",
#       "l": "1.34756",
#       "c": "1.34808"
#     },
#     "ask": {
#       "o": "1.34894",
#       "h": "1.34915",
#       "l": "1.34764",
#       "c": "1.34818"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4477,
#     "time": "2023-08-16T09:00:00.000000000Z",
#     "bid": {
#       "o": "1.34800",
#       "h": "1.34927",
#       "l": "1.34745",
#       "c": "1.34882"
#     },
#     "mid": {
#       "o": "1.34809",
#       "h": "1.34936",
#       "l": "1.34754",
#       "c": "1.34890"
#     },
#     "ask": {
#       "o": "1.34818",
#       "h": "1.34947",
#       "l": "1.34764",
#       "c": "1.34898"
#     }
#   },
#   {
#     "complete": true,
#     "volume": 4312,
#     "time": "2023-08-16T10:00:00.000000000Z",
#     "bid": {
#       "o": "1.34880",
#       "h": "1.34989",
#       "l": "1.34855",
#       "c": "1.34949"
#     },
#     "mid": {
#       "o": "1.34890",
#       "h": "1.34998",
#       "l": "1.34864",
#       "c": "1.34957"
#     },
#     "ask": {
#       "o": "1.34899",
#       "h": "1.35006",
#       "l": "1.34873",
#       "c": "1.34965"
#     }
#   },
#   {
#     "complete": false,
#     "volume": 2196,
#     "time": "2023-08-16T11:00:00.000000000Z",
#     "bid": {
#       "o": "1.34949",
#       "h": "1.34983",
#       "l": "1.34899",
#       "c": "1.34912"
#     },
#     "mid": {
#       "o": "1.34958",
#       "h": "1.34993",
#       "l": "1.34908",
#       "c": "1.34922"
#     },
#     "ask": {
#       "o": "1.34966",
#       "h": "1.35003",
#       "l": "1.34916",
#       "c": "1.34933"
#     }
#   }
# ]

# %%
#מעבר לפורמט של פנדס
#נתחיל בליצוור טבלה שהעמודות שלה זה הווליום והזמן ונסנן מתוכה רק את הנרות שכבר סיימו

# %%
final_data =[]
for candle in data:
    if candle['complete'] == False:
        continue
    new_dict = {}
    new_dict['time'] = parser.parse(candle['time'])
    new_dict['volume'] = candle['volume']
    final_data.append(new_dict)
df = pd.DataFrame.from_dict(final_data)  #ככה ממירים מילון לפנדה

# %%
df
# Out:
#                        time  volume
# 0 2023-08-16 07:00:00+00:00    5803
# 1 2023-08-16 08:00:00+00:00    4647
# 2 2023-08-16 09:00:00+00:00    4477
# 3 2023-08-16 10:00:00+00:00    4312

# %%
#הוספה של המחירים

# %%
prices = ['bid', 'mid', 'ask']
ohlc = ['o', 'h', 'l', 'c']

# %%
final_data =[]
for candle in data:
    if candle['complete'] == False:
        continue
    new_dict = {}
    new_dict['time'] = parser.parse(candle['time'])
    new_dict['volume'] = candle['volume']

    for p in prices:
        for o in ohlc:
            new_dict[f"{p}_{o}"] = float(candle[p][o])
    
    final_data.append(new_dict)
df = pd.DataFrame.from_dict(final_data)

# %%
df
# Out:
#                        time  volume    bid_o    bid_h    bid_l    bid_c  \
# 0 2023-08-16 07:00:00+00:00    5803  1.35020  1.35037  1.34808  1.34873
# 1 2023-08-16 08:00:00+00:00    4647  1.34875  1.34895  1.34746  1.34799
# 2 2023-08-16 09:00:00+00:00    4477  1.34800  1.34927  1.34745  1.34882
# 3 2023-08-16 10:00:00+00:00    4312  1.34880  1.34989  1.34855  1.34949
#
#      mid_o    mid_h    mid_l    mid_c    ask_o    ask_h    ask_l    ask_c
# 0  1.35030  1.35048  1.34817  1.34882  1.35041  1.35060  1.34826  1.34891
# 1  1.34884  1.34905  1.34756  1.34808  1.34894  1.34915  1.34764  1.34818
# 2  1.34809  1.34936  1.34754  1.34890  1.34818  1.34947  1.34764  1.34898
# 3  1.34890  1.34998  1.34864  1.34957  1.34899  1.35006  1.34873  1.34965

# %%
#נהפוך לפונקציה
#מקבל- דאטה של נרות נטו
#מחזיר- פנדה עם העמודות זמן מחיר ונפח

# %%
def get_candles_df(data):
    if len(data) == 0:
        return pd.DataFrame()

    final_data = []
    for candle in data:
        if candle['complete'] == False:
            continue
        new_dict = {}
        new_dict['time'] = parser.parse(candle['time'])
        new_dict['volume'] = candle['volume']

        for p in prices:
            for o in ohlc:
                new_dict[f"{p}_{o}"] = float(candle[p][o])
    
        final_data.append(new_dict)
    df = pd.DataFrame.from_dict(final_data)  
    return df

print(final_data)

# %%
code, data1= fetch_candles("EUR_USD", count=1, granularity="H4")
candles_df = get_candles_df(data1)
candles_df
# Out:
#                          time  volume    bid_o    bid_h    bid_l    bid_c  \
# 0   2023-08-16 07:00:00+00:00    5803  1.35020  1.35037  1.34808  1.34873
# 1   2023-08-16 08:00:00+00:00    4647  1.34875  1.34895  1.34746  1.34799
# 2   2023-08-16 09:00:00+00:00    4477  1.34800  1.34927  1.34745  1.34882
# 3   2023-08-16 10:00:00+00:00    4312  1.34880  1.34989  1.34855  1.34949
# 4   2023-08-14 21:00:00+00:00    5029  1.09101  1.09101  1.09007  1.09066
# ..                        ...     ...      ...      ...      ...      ...
# 168 2023-08-16 10:00:00+00:00    3739  1.09258  1.09262  1.09151  1.09175
# 169 2023-08-15 17:00:00+00:00   10821  1.09171  1.09204  1.08983  1.09035
# 170 2023-08-15 21:00:00+00:00    5858  1.09035  1.09060  1.08985  1.09025
# 171 2023-08-16 01:00:00+00:00   15078  1.09022  1.09128  1.08982  1.09127
# 172 2023-08-16 05:00:00+00:00   19988  1.09125  1.09340  1.09098  1.09273
#
#        mid_o    mid_h    mid_l    mid_c    ask_o    ask_h    ask_l    ask_c
# 0    1.35030  1.35048  1.34817  1.34882  1.35041  1.35060  1.34826  1.34891
# 1    1.34884  1.34905  1.34756  1.34808  1.34894  1.34915  1.34764  1.34818
# 2    1.34809  1.34936  1.34754  1.34890  1.34818  1.34947  1.34764  1.34898
# 3    1.34890  1.34998  1.34864  1.34957  1.34899  1.35006  1.34873  1.34965
# 4    1.09151  1.09151  1.09016  1.09074  1.09201  1.09201  1.09024  1.09083
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 168  1.09266  1.09270  1.09159  1.09183  1.09274  1.09277  1.09167  1.09191
# 169  1.09179  1.09211  1.08991  1.09044  1.09187  1.09218  1.08999  1.09054
# 170  1.09085  1.09106  1.08992  1.09034  1.09135  1.09156  1.09000  1.09042
# 171  1.09030  1.09136  1.08990  1.09135  1.09038  1.09144  1.08998  1.09143
# 172  1.09134  1.09347  1.09106  1.09282  1.09143  1.09354  1.09114  1.09290
#
# [173 rows x 14 columns]

# %%
#SUMMARY OF THE FUNCTIONS BY NOW

# %%
def fetch_candles(pairName, count=10, granularity="H1"):
    
    url = f"{OANDA_URL}/instruments/{pairName}/candles"
    
    params = dict(
        count = count,
        granularity = granularity,
        price = "MBA"
    )
    
    response = session.get(url, params = params, data=None, headers=None)
    data =response.json()

    if response.status_code == 200:
        if 'candles' not in data:
            data=[]
        else:
            data=data['candles']
        return response.status_code, data

def get_candles_df(data):
    if len(data) == 0:
        return pd.DataFrame()
    for candle in data:
        if candle['complete'] == False:
            continue
        new_dict = {}
        new_dict['time'] = parser.parse(candle['time'])
        new_dict['volume'] = candle['volume']

        for p in prices:
            for o in ohlc:
                new_dict[f"{p}_{o}"] = float(candle[p][o])
    
        final_data.append(new_dict)
    df = pd.DataFrame.from_dict(final_data)  
    return df

def create_data_file(pairName, count=10, granularity="H1"):
    code, data = fetch_candles(pairName, count, granularity)
    if code != 200:
        print("Failed", pairName, data)
        return
    if len(data) == 0:
        print("No candles", pairName)
    candles_df=get_candles_df(data)
    candles_df.to_pickle(f"../data/{pairName}_{granularity}.pkl")   #יוצר קובץ פיקל בשם הזה
    print(f"{pairName} {granularity} {candles_df.shape[0]} candles | from: {candles_df.time.min()} {candles_df.time.max()}")

# %%
 create_data_file1("EUR_USD")
# Out:
# EUR_USD H1 9 candles, 2023-08-16 05:00:00+00:00 2023-08-16 13:00:00+00:00

# %%
our_curr = ['EUR', 'USD', 'GBP', 'JPY', 'CHF', 'NZD','CAD', 'AUD']

for i in our_curr:
    for j in our_curr:
        pair = f"{i}_{j}"
        if pair in instruments_dict.keys():
            for g in ["H1", "H4"]:
                create_data_file(pair, count=4001, granularity = g)
# Out:
# EUR_USD H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_USD H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_GBP H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_GBP H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_JPY H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_JPY H4 4000 candles | from: 2021-01-22 14:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_CHF H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_CHF H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_NZD H1 4000 candles | from: 2022-12-23 21:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_NZD H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_CAD H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_CAD H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# EUR_AUD H1 4000 candles | from: 2022-12-23 21:00:00+00:00 2023-08-16 13:00:00+00:00
# EUR_AUD H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# USD_JPY H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# USD_JPY H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# USD_CHF H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# USD_CHF H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# USD_CAD H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
# USD_CAD H4 4000 candles | from: 2021-01-24 22:00:00+00:00 2023-08-16 09:00:00+00:00
# GBP_USD H1 4000 candles | from: 2022-12-26 22:00:00+00:00 2023-08-16 13:00:00+00:00
